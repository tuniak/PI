# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
d = []
with open('dd.txt') as dd:
    d = dd.read().splitlines()
d
# Out:
# ['1518', '775', '414', '249', '188', '108']

# %%
n = []
with open('nn.txt') as nn:
    n = nn.read().splitlines()
n
# Out:
# ['1635', '1924', '1756', '1678', '813', '667']

# %%
cores = [1,2,4,8,16,32]

# %%
fig = plt.figure()
plt.plot(cores,d, 'r-o')
plt.plot(cores,n, 'b-o')
plt.xlabel('number of threads')
plt.ylabel('seconds')
plt.title('STRONG SCALING \n timelengh of 500 steps against number of threads')
plt.show()
fig.savefig('strrongscaling.pdf')
