# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
d = []
with open('dd.txt') as dd:
    d = dd.read().splitlines()
d
# Out:
# ['407', '412', '419', '684', '1273', '852']

# %%
n = []
with open('nn.txt') as nn:
    n = nn.read().splitlines()
n
# Out:
# ['439', '978', '1343', '2254', '4162', '6644']

# %%
cores = [1,2,4,8,16,32]

# %%
fig = plt.figure()
plt.plot(cores,d, 'r-o', label='deterministic PI')
plt.plot(cores,n, 'b-o', label='non-deterministic PI')
plt.xlabel('number of threads')
plt.ylabel('seconds')
plt.title('WEAK SCALING \n timelengh of 500 steps against number of threads')
plt.show()
fig.savefig('weakkscaling.pdf')
